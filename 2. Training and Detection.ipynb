# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'directions' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
# clone the tensor flow model garden
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2024-01-04 17:05:30.710220: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Running tests under Python 3.10.11: c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0104 17:05:35.755275  8648 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2024-01-04 17:05:35.757214: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE SSE2 SSE3 SSE4.1 SSE4.2 AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0104 17:05:35.777902  8648 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0104 17:05:35.944421  8648 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.69s
# I0104 17:05:36.232059  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.69s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\models\research\object_detection\builders\model_builder_tf2_test.py:80: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0104 17:05:36.241792  8648 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\models\research\object_detection\builders\model_builder_tf2_test.py:80: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.22s
# I0104 17:05:36.454422  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.22s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.2s
# I0104 17:05:36.655390  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.2s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.18s
# I0104 17:05:36.836766  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.18s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\models\keras_models\mobilenet_v2.py:231: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0104 17:05:36.851224  8648 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\models\keras_models\mobilenet_v2.py:231: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0104 17:05:36.910753  8648 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.54s
# I0104 17:05:38.377716  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.54s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0104 17:05:38.386086  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0104 17:05:38.402738  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0104 17:05:38.413027  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0104 17:05:38.424329  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.07s
# I0104 17:05:38.495336  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# I0104 17:05:38.557726  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.07s
# I0104 17:05:38.624401  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# I0104 17:05:38.691097  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.07s
# I0104 17:05:38.757986  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0104 17:05:38.777856  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0104 17:05:38.893739  8648 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0104 17:05:38.893739  8648 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I0104 17:05:38.893739  8648 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I0104 17:05:38.895693  8648 efficientnet_model.py:143] round_filter input=32 output=32
# I0104 17:05:38.913180  8648 efficientnet_model.py:143] round_filter input=32 output=32
# I0104 17:05:38.913180  8648 efficientnet_model.py:143] round_filter input=16 output=16
# I0104 17:05:38.963105  8648 efficientnet_model.py:143] round_filter input=16 output=16
# I0104 17:05:38.964106  8648 efficientnet_model.py:143] round_filter input=24 output=24
# I0104 17:05:39.092165  8648 efficientnet_model.py:143] round_filter input=24 output=24
# I0104 17:05:39.092165  8648 efficientnet_model.py:143] round_filter input=40 output=40
# I0104 17:05:39.220577  8648 efficientnet_model.py:143] round_filter input=40 output=40
# I0104 17:05:39.220577  8648 efficientnet_model.py:143] round_filter input=80 output=80
# I0104 17:05:39.414318  8648 efficientnet_model.py:143] round_filter input=80 output=80
# I0104 17:05:39.414318  8648 efficientnet_model.py:143] round_filter input=112 output=112
# I0104 17:05:39.607591  8648 efficientnet_model.py:143] round_filter input=112 output=112
# I0104 17:05:39.607591  8648 efficientnet_model.py:143] round_filter input=192 output=192
# I0104 17:05:39.873643  8648 efficientnet_model.py:143] round_filter input=192 output=192
# I0104 17:05:39.873643  8648 efficientnet_model.py:143] round_filter input=320 output=320
# I0104 17:05:39.940357  8648 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0104 17:05:39.974734  8648 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0104 17:05:40.009759  8648 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0104 17:05:40.009759  8648 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I0104 17:05:40.009759  8648 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I0104 17:05:40.010759  8648 efficientnet_model.py:143] round_filter input=32 output=32
# I0104 17:05:40.021574  8648 efficientnet_model.py:143] round_filter input=32 output=32
# I0104 17:05:40.021574  8648 efficientnet_model.py:143] round_filter input=16 output=16
# I0104 17:05:40.114595  8648 efficientnet_model.py:143] round_filter input=16 output=16
# I0104 17:05:40.114595  8648 efficientnet_model.py:143] round_filter input=24 output=24
# I0104 17:05:40.281035  8648 efficientnet_model.py:143] round_filter input=24 output=24
# I0104 17:05:40.281035  8648 efficientnet_model.py:143] round_filter input=40 output=40
# I0104 17:05:40.446669  8648 efficientnet_model.py:143] round_filter input=40 output=40
# I0104 17:05:40.446669  8648 efficientnet_model.py:143] round_filter input=80 output=80
# I0104 17:05:40.669798  8648 efficientnet_model.py:143] round_filter input=80 output=80
# I0104 17:05:40.670810  8648 efficientnet_model.py:143] round_filter input=112 output=112
# I0104 17:05:40.891189  8648 efficientnet_model.py:143] round_filter input=112 output=112
# I0104 17:05:40.891189  8648 efficientnet_model.py:143] round_filter input=192 output=192
# I0104 17:05:41.178108  8648 efficientnet_model.py:143] round_filter input=192 output=192
# I0104 17:05:41.178108  8648 efficientnet_model.py:143] round_filter input=320 output=320
# I0104 17:05:41.307999  8648 efficientnet_model.py:143] round_filter input=1280 output=1280
# I
efficientnet_model.py:143] round_filter input=1280 output=2304
# I0104 17:05:52.769853  8648 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0104 17:05:52.834447  8648 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0104 17:05:52.834447  8648 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0104 17:05:52.834447  8648 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0104 17:05:52.835448  8648 efficientnet_model.py:143] round_filter input=32 output=64
# I0104 17:05:52.850501  8648 efficientnet_model.py:143] round_filter input=32 output=64
# I0104 17:05:52.850501  8648 efficientnet_model.py:143] round_filter input=16 output=32
# I0104 17:05:53.239224  8648 efficientnet_model.py:143] round_filter input=16 output=32
# I0104 17:05:53.239224  8648 efficientnet_model.py:143] round_filter input=24 output=48
# I0104 17:05:53.677303  8648 efficientnet_model.py:143] round_filter input=24 output=48
# I0104 17:05:53.677303  8648 efficientnet_model.py:143] round_filter input=40 output=80
# I0104 17:05:54.209658  8648 efficientnet_model.py:143] round_filter input=40 output=80
# I0104 17:05:54.209658  8648 efficientnet_model.py:143] round_filter input=80 output=160
# I0104 17:05:54.862153  8648 efficientnet_model.py:143] round_filter input=80 output=160
# I0104 17:05:54.862153  8648 efficientnet_model.py:143] round_filter input=112 output=224
# I0104 17:05:55.537142  8648 efficientnet_model.py:143] round_filter input=112 output=224
# I0104 17:05:55.537142  8648 efficientnet_model.py:143] round_filter input=192 output=384
# I0104 17:05:56.512135  8648 efficientnet_model.py:143] round_filter input=192 output=384
# I0104 17:05:56.512135  8648 efficientnet_model.py:143] round_filter input=320 output=640
# I0104 17:05:56.881154  8648 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0104 17:05:56.921071  8648 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 18.22s
# I0104 17:05:56.996956  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 18.22s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0104 17:05:57.091496  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0104 17:05:57.092497  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0104 17:05:57.092497  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0104 17:05:57.093498  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0104 17:05:57.094499  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0104 17:05:57.094499  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0104 17:05:57.094499  8648 test_util.py:2574] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 21.549s
#
# OK (skipped=1)

# %% [markdown]
# !pip install protobuf==3.20.*

# %%
# !pip install tensorflow==2.13.0
# Out:
# Collecting tensorflow==2.13.0
#   Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorflow-intel==2.13.0 (from tensorflow==2.13.0)
#   Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\absl_py-2.0.0-py3.10.egg (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\h5py-3.10.0-py3.10-win-amd64.egg (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.60.0)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-intel==2.13.0->tensorflow==2.13.0)
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.0->tensorflow==2.13.0)
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.0->tensorflow==2.13.0)
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.10-win-amd64.egg (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.2.2)
# Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl (276.5 MB)
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.15.0
#     Uninstalling tensorflow-intel-2.15.0:
#       Successfully uninstalled tensorflow-intel-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed keras-2.13.1 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-intel-2.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.15.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.15.0 requires immutabledict, which is not installed.
# tf-models-official 2.15.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.15.0 requires oauth2client, which is not installed.
# tf-models-official 2.15.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.15.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.15.0 requires sentencepiece, which is not installed.
# tf-models-official 2.15.0 requires seqeval, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-text~=2.15.0, which is not installed.
# tensorflow-decision-forests 1.8.1 requires tensorflow~=2.15.0, but you have tensorflow 2.13.0 which is incompatible.
# tf-models-official 2.15.0 requires tensorflow~=2.15.0, but you have tensorflow 2.13.0 which is incompatible.

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib

# %%
# !pip install protobuf==3.20.*

# %%
import object_detection

# %%
# !pip list

# %%
# gets the pre trained model that we will be using for custom object detection
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}

# %% [markdown]
# # 2. Create Label Map

# %%
#labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}, {'name':'ThankYou', 'id':3}, {'name':'LiveLong', 'id':4}]
labels = [{'name':'Left', 'id':1}, {'name':'Right', 'id':2}, {'name':'Up', 'id':3}, {'name':'Down', 'id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !pip install pytz

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:168: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:153: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0104 15:39:00.679384  5580 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:153: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:111: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0104 15:39:00.705018  5580 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:111: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:168: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:153: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0104 15:39:05.500458 17152 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:153: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:111: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0104 15:39:05.507546 17152 module_wrapper.py:149] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\scripts\generate_tfrecord.py:111: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\directions --pipeline_config_path=Tensorflow\workspace\models\directions\pipeline.config --num_train_steps=2000

# %%
# !{command}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)

# %%
# !pip install gin-config==0.1.1

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial() # change for the lastest checkpoint

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Left.bb11ba33-ab3d-11ee-bc14-d8bbc1d759fb.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.7,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
# Gives us our own model in the models ssdmobnet export folder
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\directions\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\directions --output_directory=Tensorflow\workspace\models\directions\export

# %%
# !{command}
# Out:
# WARNING:tensorflow:From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0104 16:12:06.928961  1228 deprecation.py:641] From c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0104 16:12:09.525536  1228 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0104 16:12:15.666886  1228 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0104 16:12:17.461070  1228 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_predictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0104 16:12:18.219190  1228 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000256BEBE1300>, because it is not built.
# W0104 16:12:19.775879  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000256BEBE1300>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256BF02C040>, because it is not built.
# W0104 16:12:20.093164  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256BF02C040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DCE80>, because it is not built.
# W0104 16:12:20.093164  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DCE80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DE2F0>, because it is not built.
# W0104 16:12:20.093164  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DE2F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DD780>, because it is not built.
# W0104 16:12:20.093164  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DD780>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DEEF0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DEEF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DE800>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DE800>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DFA30>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DFA30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DFCA0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DFCA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DEB60>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DEB60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DFE50>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x00000256C03DFE50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DE1D0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C03DE1D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DDCF0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C03DDCF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEDACA60>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEDACA60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED91030>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED91030>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED90D30>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED90D30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED91090>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED91090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED93820>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED93820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED92EF0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BED92EF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED92AD0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED92AD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BF0E47C0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BF0E47C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDC280>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDC280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDD0C0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDD0C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDD4B0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDD4B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDCBE0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDCBE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDF730>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDF730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDEFB0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDEFB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDEDA0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEDEDA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDF970>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEDF970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED72EC0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BED72EC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB87C0>, because it is not built.
# W0104 16:12:20.094165  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB87C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEBB9A0>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEBB9A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB8280>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB8280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEBA500>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEBA500>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB9F90>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB9F90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEB8790>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEEB8790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB99F0>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256BEEB99F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEFB1000>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256BEFB1000>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C1BA0>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C1BA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C2770>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C2770>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C1270>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C1270>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C2260>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C2260>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C0D60>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C0D60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C0CA0>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000256C02C0CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C3490>, because it is not built.
# W0104 16:12:20.095166  1228 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x00000256C02C3490>, because it is not built.
# I0104 16:12:27.486682  1228 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\directions\export\saved_model\assets
# I0104 16:12:31.148635  1228 builder_impl.py:804] Assets written to: Tensorflow\workspace\models\directions\export\saved_model\assets
# I0104 16:12:31.394653  1228 fingerprinting_utils.py:48] Writing fingerprint to Tensorflow\workspace\models\directions\export\saved_model\fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\directions\export\pipeline.config
# I0104 16:12:31.722679  1228 config_util.py:253] Writing pipeline config file to Tensorflow\workspace\models\directions\export\pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
#note, this must be done through the linux python env

# %%
# !pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (4.15.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.15.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.15.0 requires immutabledict, which is not installed.
# tf-models-official 2.15.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.15.0 requires oauth2client, which is not installed.
# tf-models-official 2.15.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.15.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.15.0 requires sentencepiece, which is not installed.
# tf-models-official 2.15.0 requires seqeval, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.15.0 requires tensorflow-text~=2.15.0, which is not installed.
# Requirement already satisfied: flax>=0.7.2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (0.7.5)
# Requirement already satisfied: importlib_resources>=5.9.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (6.1.1)
# Requirement already satisfied: jax>=0.4.13 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (0.4.23)
# Requirement already satisfied: jaxlib>=0.4.13 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (0.4.23)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (2.13.0)
# Collecting tensorflow-decision-forests>=1.5.0 (from tensorflowjs)
#   Using cached tensorflow_decision_forests-1.8.1-cp310-cp310-win_amd64.whl
# Requirement already satisfied: six<2,>=1.16.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.14.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (0.15.0)
# Requirement already satisfied: packaging~=23.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.24.3)
# Requirement already satisfied: msgpack in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.0.7)
# Requirement already satisfied: optax in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.7)
# Requirement already satisfied: orbax-checkpoint in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.4.4)
# Requirement already satisfied: tensorstore in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.45)
# Requirement already satisfied: rich>=11.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\rich-13.7.0-py3.10.egg (from flax>=0.7.2->tensorflowjs) (13.7.0)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (4.5.0)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from flax>=0.7.2->tensorflowjs) (6.0.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from jax>=0.4.13->tensorflowjs) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from jax>=0.4.13->tensorflowjs) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\scipy-1.12.0rc1-py3.10-win-amd64.egg (from jax>=0.4.13->tensorflowjs) (1.12.0rc1)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\absl_py-2.0.0-py3.10.egg (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\h5py-3.10.0-py3.10-win-amd64.egg (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (16.0.6)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (1.60.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.10-win-amd64.egg (from tensorflow-intel==2.13.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.31.0)
# Requirement already satisfied: pandas in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages\pandas-2.2.0rc0-py3.10-win-amd64.egg (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.0rc0)
# Collecting tensorflow<3,>=2.13.0 (from tensorflowjs)
#   Using cached tensorflow-2.15.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: wheel in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.42.0)
# Requirement already satisfied: wurlitzer in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.0.3)
# Collecting tensorflow-intel==2.15.0 (from tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs)
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.17.2)
# Requirement already satisfied: chex>=0.1.5 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.85)
# Requirement already satisfied: etils[epath,epy] in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: nest_asyncio in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.5.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2023.4)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from chex>=0.1.5->optax->flax>=0.7.2->tensorflowjs) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.1)
# Requirement already satisfied: fsspec in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2023.12.2)
# Requirement already satisfied: zipp in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\matthew\documents\coding\object dectection python\tfodcourse\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.2.2)
# Using cached tensorflow-2.15.0-cp310-cp310-win_amd64.whl (2.1 kB)
# Using cached tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl (300.9 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow-intel, tensorflow, tensorflow-decision-forests
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.13.0
#     Uninstalling tensorflow-intel-2.13.0:
#       Successfully uninstalled tensorflow-intel-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed keras-2.15.0 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-decision-forests-1.8.1 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\directions\export\saved_model Tensorflow\workspace\models\directions\tfjsexport

# %%
# !{command}
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Matthew\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Matthew\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\Scripts\tensorflowjs_converter.exe\__main__.py", line 4, in <module>
#   File "C:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflowjs\__init__.py", line 21, in <module>
#     from tensorflowjs import converters
#   File "C:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflowjs\converters\__init__.py", line 21, in <module>
#     from tensorflowjs.converters.converter import convert
#   File "C:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflowjs\converters\converter.py", line 37, in <module>
#     from tensorflowjs.converters import tf_saved_model_conversion_v2
#   File "C:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\tfod\lib\site-packages\tensorflowjs\converters\tf_saved_model_conversion_v2.py", line 28, in <module>
#     import tensorflow_decision_forests
# ModuleNotFoundError: No module named 'tensorflow_decision_forests'

# %%
# !pip list
# Out:
# Package                      Version      Editable project location
# ---------------------------- ------------ -----------------------------------------------------------------------------------------------------
# absl-py                      2.0.0
# apache-beam                  2.53.0rc2
# asttokens                    2.4.1
# astunparse                   1.6.3
# avro-python3                 1.10.2
# cachetools                   5.3.2
# certifi                      2023.11.17
# charset-normalizer           3.3.2
# chex                         0.1.85
# colorama                     0.4.6
# comm                         0.2.1
# contextlib2                  21.6.0
# contourpy                    1.2.0
# cycler                       0.12.1
# Cython                       3.0.7
# debugpy                      1.8.0
# decorator                    5.1.1
# dm-tree                      0.1.8
# etils                        1.6.0
# exceptiongroup               1.2.0
# executing                    2.0.1
# flatbuffers                  23.5.26
# flax                         0.7.5
# fonttools                    4.47.0
# fsspec                       2023.12.2
# gast                         0.4.0
# gin                          0.1.6
# gin-config                   0.1.1
# google-auth                  2.26.1
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.60.0
# h5py                         3.10.0
# idna                         3.6
# importlib-resources          6.1.1
# ipykernel                    6.28.0
# ipython                      8.19.0
# jax                          0.4.23
# jaxlib                       0.4.23
# jedi                         0.19.1
# jupyter_client               8.6.0
# jupyter_core                 5.7.0
# keras                        2.13.1
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     16.0.6
# lvis                         0.5.3
# lxml                         5.0.0
# Markdown                     3.5.1
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.3
# matplotlib                   3.8.2
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# ml-dtypes                    0.2.0
# msgpack                      1.0.7
# namex                        0.0.7
# nest-asyncio                 1.5.8
# numpy                        1.24.3
# oauthlib                     3.2.2
# object-detection             0.1
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# optax                        0.1.7
# orbax-checkpoint             0.4.4
# packaging                    23.2
# pandas                       2.2.0rc0
# parso                        0.8.3
# pillow                       10.2.0
# pip                          23.3.2
# platformdirs                 4.1.0
# portalocker                  2.8.2
# prompt-toolkit               3.0.43
# protobuf                     3.20.3
# psutil                       5.9.7
# pure-eval                    0.2.2
# pyasn1                       0.5.1
# pyasn1-modules               0.3.0
# pycocotools                  2.0.7
# Pygments                     2.17.2
# pyparsing                    2.4.7
# PyQt5                        5.15.10
# PyQt5-Qt5                    5.15.2
# PyQt5-sip                    12.13.0
# python-dateutil              2.8.2
# pytz                         2023.3.post1
# pywin32                      306
# PyYAML                       6.0.1
# pyzmq                        25.1.2
# regex                        2023.12.25
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rich                         13.7.0
# rsa                          4.9
# sacrebleu                    2.2.0
# SciPy                        1.12.0rc1
# setuptools                   65.5.0
# six                          1.16.0
# slim                         0.1          C:\Users\Matthew\Documents\Coding\Object Dectection Python\TFODCourse\Tensorflow\models\research\slim
# stack-data                   0.6.3
# tabulate                     0.9.0
# tensorboard                  2.13.0
# tensorboard-data-server      0.7.2
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.13.0
# tensorflow-estimator         2.13.0
# tensorflow-hub               0.15.0
# tensorflow-intel             2.13.0
# tensorflow-io                0.31.0
# tensorflow-io-gcs-filesystem 0.31.0
# tensorflowjs                 4.15.0
# tensorstore                  0.1.45
# termcolor                    2.4.0
# tf-models-official           2.15.0
# tf-slim                      1.1.0
# toolz                        0.12.0
# tornado                      6.4
# traitlets                    5.14.1
# typing_extensions            4.5.0
# tzdata                       2023.4
# urllib3                      2.1.0
# wcwidth                      0.2.12
# Werkzeug                     3.0.1
# wget                         3.2
# wheel                        0.42.0
# wrapt                        1.14.1
# wurlitzer                    3.0.3
# zipp                         3.17.0

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
